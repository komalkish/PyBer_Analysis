# %%
import matplotlib.pyplot as plt

# %%
saving = [0,100,150,200,900,1000]
months = ["Jan", "Feb", "March", "April", "May", "June"]

# %%
plt.plot(months,saving)

plt.xlabel(' Monthly Analysis ')
plt.ylabel('Amount in Savings $')
plt.show()
