# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import statistics
import numpy as np

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#create plot
plt.plot(x_axis, y_axis)

# %%
# Create using object oriented programming
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
#create plot and add a label,
plt.plot(x_axis, y_axis, label = "Boston",color = "blue", marker = "*")
#create label for x and Y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")
# set the ylim between 0 and 45
plt.ylim(0, 45)
#create a title
plt.title("Pyber Fare by Month")
#Add the legend
plt.legend()
#add grid
plt.grid()

# %%
#create line charts using object oriented
ax = plt.axes()
ax.plot(x_axis, y_axis, label = "Boston", marker = "D", color = "green")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.set_title("PyBer Fare by Month")
ax.grid()
ax.set_ylim(0,45)
# Out:
# (0.0, 45.0)

# %%
#create plot and add a label,
plt.bar(x_axis, y_axis, label = "Boston",color = "blue", yerr=stdev, capsize=3)
#create label for x and Y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")
#create a title
plt.title("Pyber Fare by Month")
#Add the legend
plt.legend()

# %%
#create horizontal charts
plt.barh(x_axis,y_axis, color = "cyan", label = "Boston")
plt.gca().invert_yaxis()
plt.title("Perbar")
plt.xticks(np.arange(0,51, step=5.0))
# Out:
# ([<matplotlib.axis.XTick at 0x129382790>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, label = "Chicago", c = "red", s= y_axis_larger)
plt.title("PyBer Fare by Month")
plt.ylim(0,50)
plt.xlabel("Fare ($)")
plt.ylabel("Date")
# Out:
# Text(0, 0.5, 'Date')

# %%
# bubble chart using object oriented programming
ax = plt.axes()
ax.scatter( y_axis, x_axis, label = "Boston", c = "skyblue", s = [i*5 for i in y_axis])
ax.set_title("Pyber Fare by Month")
plt.gca().invert_yaxis()
ax.set_xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x128c7d0d0>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
# ...

# %%
# using object oriented programming
explode = [0,0,0.2,0,0,0,0.2,0,0,0,0,0]
ax.invert_yaxis()
fig,ax=plt.subplots()
ax.pie(y_axis, 
       labels=x_axis, 
       explode = explode, 
       startangle=90,
       shadow=True,
       labeldistance=1.1,
       radius = 2.5,
       counterclock=False,
       autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x127634970>,
# ...
#  [Text(0.28594631393547804, 2.7350931804139162, 'Jan'),
#   Text(1.1960129024384056, 2.476298273068263, 'Feb'),
#   Text(2.627821548253653, 1.340542394157594, 'Mar'),
#   Text(2.62387602543775, -0.8232706742821567, 'April'),
#   Text(1.4661733104013155, -2.3265501980113923, 'May'),
#   Text(-0.1511608613113191, -2.745842383314749, 'June'),
#   Text(-2.0989897614034967, -2.072858408459992, 'July'),
#   Text(-2.6873898386017037, -0.5834688126886546, 'Aug'),
#   Text(-2.7494941500612953, 0.052743898023532035, 'Sept'),
#   Text(-2.496868339876031, 1.1524532499519076, 'Oct'),
#   Text(-1.6268460260850754, 2.21717658462541, 'Nov'),
#   Text(-0.5701911596208592, 2.690238287120719, 'Dec')],
#  [Text(0.1559707166920789, 1.4918690074985, '3.3%'),
#   Text(0.6523706740573121, 1.350708148946325, '7.7%'),
#   Text(1.514337841366512, 0.7725159559552236, '13.0%'),
#   Text(1.4312051047842274, -0.44905673142663094, '11.7%'),
# ...

# %%
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>
